# %%
import pandas as pd
from matplotlib import pyplot as plt
df = pd.read_csv("./bodyfind.csv")
df.sample(5)
# Out:
#       Body Size  Body Weight  Height  Bone Structure  Com1lexion
# 1080          1            1       2               0           1  \
# 773           0            1       0               0           1
# 316           1            1       1               1           1
# 868           1            1       2               0           1
# 1088          1            1       2               1           0
#
#       General feel of skin  Texture of Skin  Hair Color  A11earance of Hair
# 1080                     1                2           0                   1  \
# 773                      1                2           1                   0
# 316                      1                1           1                   1
# 868                      1                2           0                   1
# 1088                     0                0           0                   0
#
#       Sha1e of face  ...  Eyelashes  Blinking of Eyes  Cheeks  Nose
# ...

# %%
cols = list(df.columns)

# %%
# %matplotlib inline

# %%
for lab in cols[:-1]:
    plt.hist(df[df["Dosha"]==0][lab],color='b',alpha = 0.6, density = True, label='vata')
    plt.hist(df[df["Dosha"]==1][lab],color='r',alpha = 0.6, density = True, label='pitta')    
    plt.hist(df[df["Dosha"]==2][lab],color='g',alpha = 0.6, density = True, label='kapha')  
    plt.xlabel(lab)
    plt.ylabel('Probability')
    plt.title(lab)
    plt.legend()
    plt.show()

# %%
X = df.drop('Dosha', axis ='columns')
y = df['Dosha']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.2);
X_train.shape,X_test.shape
# Out:
# ((960, 20), (240, 20))

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test, y_test)
# Out:
# 1.0

# %%
y_pred = model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[ 54,   0,   0,   0,   0,   0],
#        [  0,  24,   0,   0,   0,   0],
#        [  0,   0,  17,   0,   0,   0],
#        [  0,   0,   0, 131,   0,   0],
#        [  0,   0,   0,   0,   3,   0],
#        [  0,   0,   0,   0,   0,  11]])

# %%
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel("Truth")
plt.ylabel('Predicted')
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()

# %%
from joblib import load, dump
dump(model,'./trained_model')
# Out:
# ['./trained_model']

# %%
test_value = df.sample()
test_value = test_value[:-1]
