# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report
# Out:
# C:\Users\prath\AppData\Local\Temp\ipykernel_4976\1103399908.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df=pd.read_csv("../dataset/data.csv")
df
# Out:
#       Body Size  Body Weight  Height  Bone Structure  Com1lexion  \
# 0             1            1       1               2           2
# 1             1            1       0               1           1
# 2             0            1       1               1           1
# 3             0            1       0               0           1
# 4             2            1       0               1           0
# ...         ...          ...     ...             ...         ...
# 1195          1            1       0               1           1
# 1196          1            1       2               1           1
# 1197          0            0       1               0           1
# 1198          2            2       1               2           1
# 1199          2            1       2               2           1
#
#       General feel of skin  Texture of Skin  Hair Color  A11earance of Hair  \
# 0                        0                0           0                   1
# 1                        0                2           1                   0
# 2                        1                2           0                   0
# 3                        0                2           0                   1
# 4                        1                2           0                   0
# ...                    ...              ...         ...                 ...
# 1195                     1                2           0                   0
# 1196                     1                2           0                   0
# 1197                     1                2           0                   2
# 1198                     1                2           0                   1
# 1199                     0                2           0                   1
#
#       Sha1e of face  ...  Eyelashes  Blinking of Eyes  Cheeks  Nose  \
# 0                 0  ...          1                 1       0     2
# 1                 0  ...          1                 1       1     2
# 2                 0  ...          1                 1       1     2
# 3                 2  ...          0                 1       1     0
# 4                 0  ...          0                 1       0     1
# ...             ...  ...        ...               ...     ...   ...
# 1195              0  ...          1                 1       0     2
# 1196              0  ...          1                 1       1     0
# 1197              1  ...          1                 0       0     0
# 1198              2  ...          1                 1       2     2
# 1199              0  ...          1                 1       1     2
#
#       Teeth and gums  Li1s  Nails  A11etite  Liking tastes  Dosha
# 0                  2     0      2         2              0      3
# 1                  1     0      0         2              0      3
# 2                  1     1      1         2              0      1
# 3                  1     1      0         2              0      3
# 4                  1     1      1         1              1      3
# ...              ...   ...    ...       ...            ...    ...
# 1195               1     1      0         2              0      3
# 1196               1     1      0         1              0      3
# 1197               0     1      1         0              0      3
# 1198               1     1      0         2              0      4
# 1199               1     1      0         0              0      3
#
# [1200 rows x 21 columns]

# %%
X=df.drop(columns="Dosha")
X
# Out:
#       Body Size  Body Weight  Height  Bone Structure  Com1lexion  \
# 0             1            1       1               2           2
# 1             1            1       0               1           1
# 2             0            1       1               1           1
# 3             0            1       0               0           1
# 4             2            1       0               1           0
# ...         ...          ...     ...             ...         ...
# 1195          1            1       0               1           1
# 1196          1            1       2               1           1
# 1197          0            0       1               0           1
# 1198          2            2       1               2           1
# 1199          2            1       2               2           1
#
#       General feel of skin  Texture of Skin  Hair Color  A11earance of Hair  \
# 0                        0                0           0                   1
# 1                        0                2           1                   0
# 2                        1                2           0                   0
# 3                        0                2           0                   1
# 4                        1                2           0                   0
# ...                    ...              ...         ...                 ...
# 1195                     1                2           0                   0
# 1196                     1                2           0                   0
# 1197                     1                2           0                   2
# 1198                     1                2           0                   1
# 1199                     0                2           0                   1
#
#       Sha1e of face  Eyes  Eyelashes  Blinking of Eyes  Cheeks  Nose  \
# 0                 0     1          1                 1       0     2
# 1                 0     1          1                 1       1     2
# 2                 0     0          1                 1       1     2
# 3                 2     1          0                 1       1     0
# 4                 0     0          0                 1       0     1
# ...             ...   ...        ...               ...     ...   ...
# 1195              0     2          1                 1       0     2
# 1196              0     0          1                 1       1     0
# 1197              1     0          1                 0       0     0
# 1198              2     1          1                 1       2     2
# 1199              0     1          1                 1       1     2
#
#       Teeth and gums  Li1s  Nails  A11etite  Liking tastes
# 0                  2     0      2         2              0
# 1                  1     0      0         2              0
# 2                  1     1      1         2              0
# 3                  1     1      0         2              0
# 4                  1     1      1         1              1
# ...              ...   ...    ...       ...            ...
# 1195               1     1      0         2              0
# 1196               1     1      0         1              0
# 1197               0     1      1         0              0
# 1198               1     1      0         2              0
# 1199               1     1      0         0              0
#
# [1200 rows x 20 columns]

# %%
Y=df["Dosha"]
Y
# Out:
# 0       3
# 1       3
# 2       1
# 3       3
# 4       3
#        ..
# 1195    3
# 1196    3
# 1197    3
# 1198    4
# 1199    3
# Name: Dosha, Length: 1200, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=42)
x_train
# Out:
#       Body Size  Body Weight  Height  Bone Structure  Com1lexion  \
# 331           1            1       0               1           1
# 409           1            1       0               1           1
# 76            1            0       0               1           0
# 868           1            1       2               0           1
# 138           2            1       0               1           0
# ...         ...          ...     ...             ...         ...
# 1044          2            2       1               1           1
# 1095          1            1       0               1           1
# 1130          1            0       1               0           1
# 860           0            1       0               1           0
# 1126          0            0       1               1           0
#
#       General feel of skin  Texture of Skin  Hair Color  A11earance of Hair  \
# 331                      0                2           0                   0
# 409                      1                2           0                   1
# 76                       0                2           1                   0
# 868                      1                2           0                   1
# 138                      0                2           0                   0
# ...                    ...              ...         ...                 ...
# 1044                     2                1           1                   2
# 1095                     1                2           0                   0
# 1130                     1                2           1                   0
# 860                      0                2           0                   2
# 1126                     1                1           0                   2
#
#       Sha1e of face  Eyes  Eyelashes  Blinking of Eyes  Cheeks  Nose  \
# 331               0     2          0                 0       0     1
# 409               0     0          1                 1       1     0
# 76                0     0          0                 2       0     0
# 868               0     0          1                 1       0     1
# 138               1     1          0                 2       2     0
# ...             ...   ...        ...               ...     ...   ...
# 1044              2     2          1                 1       2     1
# 1095              0     2          1                 1       0     2
# 1130              1     1          0                 0       1     2
# 860               0     0          0                 1       1     1
# 1126              0     1          1                 2       2     0
#
#       Teeth and gums  Li1s  Nails  A11etite  Liking tastes
# 331                1     0      0         1              0
# 409                0     0      0         1              1
# 76                 1     0      0         0              0
# 868                0     1      1         1              0
# 138                1     0      2         0              1
# ...              ...   ...    ...       ...            ...
# 1044               1     0      0         1              2
# 1095               1     1      0         2              0
# 1130               0     1      1         0              1
# 860                0     0      1         2              0
# 1126               0     0      1         2              2
#
# [960 rows x 20 columns]

# %%
model=RandomForestClassifier()
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([1, 3, 3, 3, 5, 1, 3, 0, 2, 3, 1, 4, 1, 1, 0, 3, 3, 3, 3, 3, 3, 3,
#        0, 4, 3, 3, 3, 3, 5, 4, 3, 1, 1, 4, 3, 3, 4, 3, 3, 0, 3, 3, 1, 3,
#        2, 0, 3, 3, 3, 3, 3, 0, 3, 5, 0, 5, 3, 0, 3, 3, 3, 3, 3, 3, 3, 1,
#        3, 3, 1, 3, 4, 0, 0, 3, 1, 3, 2, 0, 0, 2, 5, 3, 4, 3, 1, 3, 0, 0,
#        3, 0, 3, 0, 3, 3, 3, 3, 3, 3, 1, 3, 0, 0, 0, 3, 3, 3, 3, 1, 3, 0,
#        3, 3, 0, 0, 3, 3, 4, 5, 3, 1, 3, 3, 3, 3, 3, 3, 4, 3, 1, 3, 0, 0,
#        1, 3, 0, 3, 3, 1, 3, 4, 3, 3, 1, 0, 3, 5, 2, 3, 3, 3, 1, 2, 3, 3,
#        3, 3, 3, 0, 1, 1, 3, 4, 5, 3, 3, 3, 3, 3, 3, 0, 3, 3, 0, 4, 3, 0,
#        1, 0, 3, 3, 5, 3, 1, 3, 3, 3, 3, 3, 0, 1, 3, 1, 3, 0, 3, 4, 1, 1,
#        3, 0, 1, 3, 0, 0, 3, 1, 3, 2, 3, 3, 3, 3, 0, 4, 3, 3, 0, 0, 0, 5,
#        0, 3, 3, 2, 1, 0, 3, 3, 0, 1, 3, 0, 2, 4, 0, 0, 3, 0, 1, 0],
#       dtype=int64)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
df
# Out:
#       Body Size  Body Weight  Height  Bone Structure  Com1lexion  \
# 0             1            1       1               2           2
# 1             1            1       0               1           1
# 2             0            1       1               1           1
# 3             0            1       0               0           1
# 4             2            1       0               1           0
# ...         ...          ...     ...             ...         ...
# 1195          1            1       0               1           1
# 1196          1            1       2               1           1
# 1197          0            0       1               0           1
# 1198          2            2       1               2           1
# 1199          2            1       2               2           1
#
#       General feel of skin  Texture of Skin  Hair Color  A11earance of Hair  \
# 0                        0                0           0                   1
# 1                        0                2           1                   0
# 2                        1                2           0                   0
# 3                        0                2           0                   1
# 4                        1                2           0                   0
# ...                    ...              ...         ...                 ...
# 1195                     1                2           0                   0
# 1196                     1                2           0                   0
# 1197                     1                2           0                   2
# 1198                     1                2           0                   1
# 1199                     0                2           0                   1
#
#       Sha1e of face  ...  Eyelashes  Blinking of Eyes  Cheeks  Nose  \
# 0                 0  ...          1                 1       0     2
# 1                 0  ...          1                 1       1     2
# 2                 0  ...          1                 1       1     2
# 3                 2  ...          0                 1       1     0
# 4                 0  ...          0                 1       0     1
# ...             ...  ...        ...               ...     ...   ...
# 1195              0  ...          1                 1       0     2
# 1196              0  ...          1                 1       1     0
# 1197              1  ...          1                 0       0     0
# 1198              2  ...          1                 1       2     2
# 1199              0  ...          1                 1       1     2
#
#       Teeth and gums  Li1s  Nails  A11etite  Liking tastes  Dosha
# 0                  2     0      2         2              0      3
# 1                  1     0      0         2              0      3
# 2                  1     1      1         2              0      1
# 3                  1     1      0         2              0      3
# 4                  1     1      1         1              1      3
# ...              ...   ...    ...       ...            ...    ...
# 1195               1     1      0         2              0      3
# 1196               1     1      0         1              0      3
# 1197               0     1      1         0              0      3
# 1198               1     1      0         2              0      4
# 1199               1     1      0         0              0      3
#
# [1200 rows x 21 columns]

# %%
df.iloc[4,:].to_numpy()
# Out:
# array([2, 1, 0, 1, 0, 1, 2, 0, 0, 0, 0, 0, 1, 0, 1, 1, 1, 1, 1, 1, 3],
#       dtype=int64)

# %%
model.predict([X.iloc[5,:].to_numpy()])[0]
# Out:
# d:\Code\Prakriti\bot\project\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 3

# %%
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[ 48,   0,   0,   0,   0,   0],
#        [  0,  33,   0,   0,   0,   0],
#        [  0,   0,   9,   0,   0,   0],
#        [  0,   0,   0, 125,   0,   0],
#        [  0,   0,   0,   0,  15,   0],
#        [  0,   0,   0,   0,   0,  10]], dtype=int64)

# %%
# pip install seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(cm,annot=True,fmt=".0f",cmap="Blues")
# Out:
# <Axes: >
